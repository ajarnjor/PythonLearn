# %%
import pandas as pd
import requests
import bs4
import io
from bs4 import BeautifulSoup as soup
from PIL import Image

# %%
my_url = 'https://www.liverpoolfc.com/team/first-team'

# %%
r = requests.get(my_url)
r.status_code
# Out:
# 200

# %%
r.content
# Out:
# b'<!DOCTYPE html>\n<!--[if lt IE 7 ]> <html xmlns="http://www.w3.org/1999/xhtml" xmlns:og="http://opengraphprotocol.org/schema/" prefix="og: http://ogp.me/ns#" id="top" class="no-js ie6 oldie"> <![endif]-->\n<!--[if IE 7 ]>    <html xmlns="http://www.w3.org/1999/xhtml" xmlns:og="http://opengraphprotocol.org/schema/" prefix="og: http://ogp.me/ns#" id="top" class="no-js ie7 oldie"> <![endif]-->\n<!--[if IE 8 ]>    <html xmlns="http://www.w3.org/1999/xhtml" xmlns:og="http://opengraphprotocol.org/schema/" prefix="og: http://ogp.me/ns#" id="top" class="no-js ie8 oldie"> <![endif]-->\n<!--[if IE 9 ]>    <html xmlns="http://www.w3.org/1999/xhtml" xmlns:og="http://opengraphprotocol.org/schema/" prefix="og: http://ogp.me/ns#" id="top" class="no-js ie9"> <![endif]-->\n<!--[if (gt IE 9)|!(IE)]><!--> <html id="top" class="no-js"> <!--<![endif]-->\n<script>\n    (function(H){H.className=H.className.replace(/\\bno-js\\b/,\'js\')})(document.documentElement);\n\n    if (window.history.replaceState && window.location.href.slice(-1) === \'#\') {\n        window.history.replaceState({},document.title,window.location.href.slice(0,-1));\n    }\n</script>\n        <head >\n\n                        <title>Liverpool FC - Team</title>\n        <meta name="keywords" content="Liverpool FC Team, lfc first team, first team, liverpool football club team, Mohamed Salah, Sadio Mane, Roberto Firmino, Philippe Coutinho, James Milner, Jordan Henderson, Adam Lallana, Ben Woodburn" />\n<meta name="description" content="The official home of the Liverpool FC first team. Discover profiles, images and videos featuring all of your LFC players." />\n<meta name="robots" content="index, follow" />\n<meta property="og:site_name" content="Liverpool FC" />\n<meta property="og:description" content="The official home of the Liverpool FC first team. Discover profiles, images and videos featuring all of your LFC players." />\n<meta property="og:type" content="article" />\n<meta property="fb:pages" content="67920382572" />\n<meta property="og:title" content="Liverpool FC - Team" />\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n<meta charset="UTF-8" />\n\n\n        <meta name="viewport" content="initial-scale=1.0, width=device-width" />\n        <meta http-equiv="X-UA-Compatible" content="IE=edge" />\n                          <link rel="shortcut icon" href="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-271/lfc/images/favicon.png" type="image/png" />\n                  \n\n            <link rel="stylesheet" href="https://secure.widget.cloud.opta.net/2.0/css/widgets.opta.css" type="text/css">\n\n            <!--[if IE 9]>\n                <link rel="stylesheet" type="text/css" href="https://secure.widget.cloud.opta.net/2.0/css/ie9.widgets.opta.css" media="screen" />\n            <![endif]-->\n\n            <!--[if IE 8]>\n                <link rel="stylesheet" type="text/css" href="https://secure.widget.cloud.opta.net/2.0/css/ie8.widgets.opta.css" media="screen" />\n            <![endif]-->\n\n            <!--[if IE 7]>\n                <link rel="stylesheet" type="text/css" href="https://secure.widget.cloud.opta.net/2.0/css/ie7.widgets.opta.css" media="screen" />\n            <![endif]-->\n\n                <link rel="stylesheet" href="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-271/lfc/css/styles.css" />\n        \n                <!--[if  (lt IE 9) & (!IEMobile)]>\n            <link rel="stylesheet" href="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-271/lfc/css/styles-ie8.css" />\n        <![endif]-->\n        \n                \n                <!--[if lt IE 9]>\n            <script src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-271/lfc/js/polyfills-ie8.min.js"></script>\n        <![endif]-->\n        \n                <!--[if IE 9]>\n        <script src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-271/lfc/js/polyfills-ie9.min.js"></script>\n        <![endif]-->\n        \n        \n    \n                        <script src="https://d3j2s6hdd6a7rg.clo ...

# %%
s = soup(r.text,"lxml")
type(s)
# Out:
# bs4.BeautifulSoup

# %%
print(s.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7 ]> <html xmlns="http://www.w3.org/1999/xhtml" xmlns:og="http://opengraphprotocol.org/schema/" prefix="og: http://ogp.me/ns#" id="top" class="no-js ie6 oldie"> <![endif]-->
# <!--[if IE 7 ]>    <html xmlns="http://www.w3.org/1999/xhtml" xmlns:og="http://opengraphprotocol.org/schema/" prefix="og: http://ogp.me/ns#" id="top" class="no-js ie7 oldie"> <![endif]-->
# <!--[if IE 8 ]>    <html xmlns="http://www.w3.org/1999/xhtml" xmlns:og="http://opengraphprotocol.org/schema/" prefix="og: http://ogp.me/ns#" id="top" class="no-js ie8 oldie"> <![endif]-->
# <!--[if IE 9 ]>    <html xmlns="http://www.w3.org/1999/xhtml" xmlns:og="http://opengraphprotocol.org/schema/" prefix="og: http://ogp.me/ns#" id="top" class="no-js ie9"> <![endif]-->
# <!--[if (gt IE 9)|!(IE)]><!-->
# <html class="no-js" id="top">
#  <!--<![endif]-->
#  <head>
#   <script>
#    (function(H){H.className=H.className.replace(/\bno-js\b/,'js')})(document.documentElement);
#
#     if (window.history.replaceState && window.location.href.slice(-1) === '#') {
#         window.history.replaceState({},document.title,window.location.href.slice(0,-1));
#     }
#   </script>
#   <title>
#    Liverpool FC - Team
#   </title>
#   <meta content="Liverpool FC Team, lfc first team, first team, liverpool football club team, Mohamed Salah, Sadio Mane, Roberto Firmino, Philippe Coutinho, James Milner, Jordan Henderson, Adam Lallana, Ben Woodburn" name="keywords"/>
#   <meta content="The official home of the Liverpool FC first team. Discover profiles, images and videos featuring all of your LFC players." name="description"/>
#   <meta content="index, follow" name="robots"/>
#   <meta content="Liverpool FC" property="og:site_name"/>
#   <meta content="The official home of the Liverpool FC first team. Discover profiles, images and videos featuring all of your LFC players." property="og:description"/>
#   <meta content="article" property="og:type"/>
#   <meta content="67920382572" property="fb:pages"/>
#   <meta content="Liverpool FC - Team" property="og:title"/>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta charset="utf-8"/>
#   <meta content="initial-scale=1.0, width=device-width" name="viewport"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <link href="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-271/lfc/images/favicon.png" rel="shortcut icon" type="image/png"/>
#   <link href="https://secure.widget.cloud.opta.net/2.0/css/widgets.opta.css" rel="stylesheet" type="text/css"/>
#   <!--[if IE 9]>
#                 <link rel="stylesheet" type="text/css" href="https://secure.widget.cloud.opta.net/2.0/css/ie9.widgets.opta.css" media="screen" />
#             <![endif]-->
#   <!--[if IE 8]>
#                 <link rel="stylesheet" type="text/css" href="https://secure.widget.cloud.opta.net/2.0/css/ie8.widgets.opta.css" media="screen" />
#             <![endif]-->
#   <!--[if IE 7]>
#                 <link rel="stylesheet" type="text/css" href="https://secure.widget.cloud.opta.net/2.0/css/ie7.widgets.opta.css" media="screen" />
#             <![endif]-->
#   <link href="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-271/lfc/css/styles.css" rel="stylesheet"/>
#   <!--[if  (lt IE 9) & (!IEMobile)]>
#             <link rel="stylesheet" href="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-271/lfc/css/styles-ie8.css" />
#         <![endif]-->
#   <!--[if lt IE 9]>
#             <script src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-271/lfc/js/polyfills-ie8.min.js"></script>
#         <![endif]-->
#   <!--[if IE 9]>
#         <script src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-271/lfc/js/polyfills-ie9.min.js"></script>
#         <![endif]-->
#   <script src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-271/lfc/js/base.js">
#   </script>
#   <script>
#    // create Lfc element with GPT command queue
#  var Lfc = Lfc || {};
#  Lfc.gtmAdQueue = Lfc.gtmAdQueue || [];
#
#  // Load GPT asynchronously
#  var googletag = googletag || {};
#  googletag.cmd = googletag.cmd || [];
#  (function() {
#    var gads = document.createElement('script');
#    gads.async = true;
#    var useSSL = 'https:' == document.location.protocol;
#    gads.src = (useSSL ? 'https:' : 'http:') +
#        '//www.googletagservices.com/tag/js/gpt.js';
#    var node = document.getElementsByTagName('script')[0];
#    node.parentNode.insertBefore(gads, node);
#  })();
#   </script>
#   <script>
#    $( document ).ready(function() {
#         $('.masthead .link-login a')
#             .attr('href', '/my-lfc/login?fragment=&referer='+(document.URL));
#
# // remove age restricted footer logos
# var checkString = window.location.href;
# if( checkString.indexOf("academy") !== -1 || checkString.indexOf("under-23") !== -1 || checkString.indexOf("under-18") !== -1 || checkString.indexOf("soccerschools") !== -1  || checkString.indexOf("soccer-schools") !== -1  || checkString.indexOf("u23") !== -1  || checkString.indexOf("u18") !== -1){
# $('a[title="Carlsberg"], a[title="Betvictor"], a[title="Liverpool Vodka"], a[title="Draft Kings"]').remove();
# }
#
#           })
#   </script>
#   <style>
#    .site-header-inner .masthead .masthead-links .more-menu ul li a {
#   background: none!important;
# }
# .site-header-inner .social-links li.skype {
#   display: none;
# }
# .vixlet {
#    display:none !important;
# }
# .video-error__content {
# padding-top:3%!important;
# }
# .video-error__listing {
# margin:15px 0!important;
# }
#
# .video-error__subtitle-mobile,
# .video-error__registered {
# color:white!important;
# }
#
# .video-player-embeddable .video-error--embed .video-error__listing-group ul li {
# margin:0 0 5px 0!important;
# }
# .video-error__call-to-action a.js-subscribe-button {
# font-size:0.8em!important;
# background:white!important;
# text-transform:uppercase!important;
# }
# .video-error__call-to-action a.js-subscribe-button:hover {
# color:#e31b23!important;
# }
#
# @media only screen and (min-width: 551px) {
# .video-error__subtitle-mobile {
# margin:10px 0!important;
# padding:0!important;
# }
# }
#
# @media only screen and (min-width: 775px) and (max-width: 975px) {
# .video-error__listing-group {
# display:none!important;
# }
# }
#
# /* IE ONLY */
# @media screen\0 {
# .video-player-embeddable .video .shard-overlay {position: absolute !important;}
# }
#
# .home .featured-news-carousel .media-image-wrap .indent {text-indent: -99999px;}
#   </style>
#   <script>
#    var Lfc = Lfc || {};
#
# Lfc.messagesConfig = {
#     messages: [
#         // COOKIE NOTIFICATION
#         {
#             id: 'cookie-notification',
#             maximumDisplayCount: 1,
#             content: '<div class="cookie-message-wrapper"><p>This site uses cookies. By continuing to browse the site you are consenting to their use. <a href="http://www.liverpoolfc.com/legal/cookies" target="_blank">View cookie policy.</a></p><a href="javascript:void(0);" class="close">ACCEPT & CLOSE</a></div>',
#             style: 'bottom-overlay',
#             displayCondition: function() {
#                 // don't show on app pages
#                 var pathStart = window.location.pathname.substr(0,5);
#                 if (pathStart == "/app/" || pathStart == "/app") {
#                     return false;
#                 }
#                 // don't show if already been shown anywhere
#                 return !Lfc.Cookie.has('cookie-notification-shown', true);
#             },
#             onShow: function() {
#                 // set cross-subdomain cookie so all microsites know this has been shown
#                 Lfc.Cookie.set('cookie-notification-shown', '1', true);
#             }
#         },
#
#         // ANDROID APP BANNER
#         {
#             id: 'android-app-banner',
#             maximumDisplayCount: 1,
#             displayCondition: function() {
#                 // don't show on non-Android devices
#                 if (navigator.userAgent.match(/Android/i) === null || navigator.userAgent.indexOf('Windows') > -1) {
#                     return false;
#                 }
#                 // only show on home and news pages
#                 var pathStart = window.location.pathname.substr(0,6);
#                 if (pathStart != "/news/" && pathStart != "/news" && pathStart != "/") {
#                     return false;
#                 }
#                 // only show if valid app id meta tag exists
#                 //  (e.g. <meta name="google-play-app" content="app-id=tv.liverpoolfc">)
#                 var $meta = $('meta[name="google-play-app"]');
#                 if ($meta.length > 0) {
#                     var appId = /app-id=([^\s,]+)/.exec($meta.attr('content'));
#                     if (appId) {
#                         return true;
#                     }
#                 }
#             },
#             content: function() {
#                 // get app id from meta tag
#                 var $meta = $('meta[name="google-play-app"]');
#                 if ($meta.length > 0) {
#                     var appId = /app-id=([^\s,]+)/.exec($meta.attr('content'));
#                     if (appId) {
#                         var linkUrl = 'https://play.google.com/store/apps/details?id=' + appId[1] +
#                                 '&referrer=utm_source%3DWebsite%26utm_medium%3DHEADER_APP_CARD_MAIN_SITE%26utm_content%3DDigital%26utm_campaign%3DClub%2520App';
#
#                         return '<div id="android-app-banner">' +
#                             '<a href="javascript:void(0);" class="close">&times;</a>' +
#                             '<a href="' + linkUrl + '">' +
#                                 '<span class="app-icon"></span>' +
#                                 '<div class="app-info">' +
#                                     '<strong>LFC Official App</strong>' +
#                                     '<span>Liverpool Football Club</span>' +
#                                     '<span>FREE in Google Play</span>' +
#                                 '</div>' +
#                                 '<span class="view">VIEW</span>' +
#                             '</a>' +
#                         '</div>';
#                     }
#                 }
#             },
#             style: "styled-header"
#         },
#
#         // REGISTRATION POP-UP
#         {
#             id : 'registration-popup',
#             minimumInterval : 10*24*60*60*1000, // 10 days = 10*24*60*60*1000
#             displayCondition: function() {
#                 // don't show to logged in users
#                 if (Lfc.Login.isLoggedIn()) {
#                     Lfc.Cookie.set("registration-popup-logout-time", "logged in");
#                     return false;
#                 }
#                 // don't show immediately after logout -- wait 1 day
#                 var now = (new Date()).getTime(),
#                     logOutTime = Lfc.Cookie.get("registration-popup-logout-time");
#
#                 if (logOutTime == "logged in") {
#                     // immediately after logout, store timestamp
#                     Lfc.Cookie.set("registration-popup-logout-time", now);
#                     return false;
#                 } else {
#                     // if one day has not yet passed since first known logged out time, don't show
#                     if (logOutTime && (now - logOutTime < 24*60*60*1000)) { // 1 day = 24*60*60*1000
#                         return false;
#                     };
#                 }
#                 // only show on home and news pages
#                 var pathStart = window.location.pathname.substr(0,6);
#                 if (pathStart != "/news/" && pathStart != "/news" && pathStart != "/") {
#                     return false;
#                 }
#                 // only show to "A" group people
#                 var abGroup = Lfc.Cookie.getABGroup("registration-popup");
#                 if (!abGroup) {
#                     abGroup = Lfc.Cookie.setABGroup("registration-popup");
#                     dataLayer.push({'event': 'registration-popup-ab-assignment', 'abGroup': abGroup });
#                 }
#                 return abGroup === "A";
#             },
#             onShow: function() {
#                 dataLayer.push({'event': 'registration-popup-shown'});
#             },
#             content : function() {
#                 if ($(window).width() < 1000) {
#                     // header message
#                     return regMessageHeaderMarkup + regMessageHeaderStyling;
#                 } else {
#                     // big popup with login
#                     return regMessagePopupMarkup + regMessagePopupStyling;
#                 }
#             },
#             style: function() {
#                 if ($(window).width() < 1000) {
#                     return 'default-header';
#                 } else {
#                     return 'popup';
#                 }
#             }
#         },
#     ],
#     minimumMessageInterval : 60*60*1000, // 1 hour = 60*60*1000
# }
#
#
# // REGISTRATION POPUP MARKUP & STYLING
# var regMessagePopupMarkup = '<div class="registration-popup-message"> <h1>GET MORE FROM LFC.</h1> <div id="not-logged-in-actions"> <h2>Register and get immediate access to:</h2> <fieldset class="reg-signup"> <div class="new-user-content"> <div class="signUpMessage registerText" style="line-height: 24px;"> <ul> <li class="image-bullet video">Free LFC videos</li> <li class="image-bullet match">Listen to live match commentary</li> <li class="image-bullet win">Exclusive competitions</li> <li class="image-bullet news">Receive the official club newsletter - All in Red</li> <li class="image-bullet forum">Join the conversation on the official LFC forums</li> <li class="image-bullet shirt">The Official Online Store</li> </ul> <p>...and it&rsquo;s completely <span>FREE!</span></p> </div> </div> <a href="/my-lfc/join/user-details?user_type=free&source=audbuild"> <div class="buttonPlaceholder buttonPlaceholderPopUp"> <input type="button" value="Register" class="btn right metroButton"/> <span class="buttonIcon"></span> </div> </a> </fieldset> </div> <div id="LoginBox"> <h2>Login</h2> <div class="LoginFormBox"> <form id="WholesaleContact" title="Login" method="post" name="Login" action="/scripts/login.php?login=LfcTVLogin"> <fieldset> <div class="login-content"> <div id="socialSignOn"> <div class="right socialLogin twitterButton" onclick="socialSignOnInitialise(\'Twitter\',\'http://www.liverpoolfc.com/\',\'/my-lfc/join/user-details\')"><a class="socialText" href="javascript:void(0);">Twitter</a></div> <div class="right socialLogin googleButton" onclick="socialSignOnInitialise(\'Google\',\'http://www.liverpoolfc.com/\',\'/my-lfc/join/user-details\')" ><a class="socialText" style="margin-left: 65px;" href="javascript:void(0);">Google</a></div> <div class="right socialLogin facebookButton" onclick="socialSignOnInitialise(\'Facebook\',\'http://www.liverpoolfc.com/\',\'/my-lfc/join/user-details\')"><a class="socialText" href="javascript:void(0);">Facebook</a></div> </div> <table class="lfcMembershipTable"> <tr class="LoginTableSpacing"> <th><label for="LoginUsernameId">Username</label></th> <td><input id="LoginUsernameId" class="InputLoginBox " type="text" name="username" /></td> <td class="formHelp">Email address</td> </tr> <tr class="LoginTableSpacing"> <th><label for="LoginPasswordId">Password</label></th> <td><input id="LoginPasswordId" class="InputLoginBox" type="password" name="password" /></td> <td class="formHelp"> <p><a href="/my-lfc/login/forgotten-password">Forgotten password?</a></p> </td> </tr> <tr class="remember LoginTableSpacing"> <th><label for="remember_me">Remember</label></th> <td style="vertical-align: middle;" class="rememberSideText formHelp" colspan="2"> <input type="checkbox" name="remember_me" class="remember_checkbox" /> <p class="rememberSideText formHelp">Remember your details on this machine?</p> </td> </tr> </table> </div> <div class="ArticleContent"> <div class="buttonPlaceholder"> <input type="submit" value="Login" class="btn right metroButton"/> <span class="buttonIcon"></span> </div> </div> <input type="hidden" name="referer" value="http://www.liverpoolfc.com/" /> </fieldset> </form> <script type="text/javascript"> $("#LoginUsernameId, #LoginPasswordId").on("keydown", function (evt) { if(evt.keyCode == 13) { $("#LoginForm").submit(); } }); <\/script> </div> </div></div>';
#
# var regMessagePopupStyling = '<style> /* header */ #cboxLoadedContent .registration-popup-message h1 { background: #E31B23; color: #FFF; padding: 0px 20px; line-height: 64px; font-size: 30px; } #colorbox #cboxClose { background: none; height: 58px; width: 50px; top: 3px; right: 3px; border: none; } #colorbox #cboxClose::after { content: "\\2716"; position: absolute; top: 0; left: 0; right: 0; line-height: 58px; text-align: center; font-size: 24px; text-indent: 0; color: #fff; } /* layout */ #cboxLoadedContent .registration-popup-message #not-logged-in-actions { width: 65%; padding: 20px; } #cboxLoadedContent .registration-popup-message #LoginBox { width: 35%; padding: 20px; } #cboxLoadedContent .registration-popup-message .login-content, #cboxLoadedContent .registration-popup-message .new-user-content { height: 250px; } #cboxLoadedContent .registration-popup-message h2 { border-bottom: 1px solid #DDD; margin: 0; padding: 2px 0 8px; } /* registration benefits */ #cboxLoadedContent .registration-popup-message .signUpMessage > p, #cboxLoadedContent .registration-popup-message .signUpMessage > ul { line-height: 36px; font-size: 16px; margin-bottom: 12px; } #cboxLoadedContent .registration-popup-message .signUpMessage > ul li.image-bullet { background-size: 24px; padding-left: 36px; } #cboxLoadedContent .registration-popup-message .signUpMessage > p { line-height: 36px; font-size: 16px; } /* login form */ #cboxLoadedContent .registration-popup-message #socialSignOn { margin: -10px 0 0; } #cboxLoadedContent .registration-popup-message .socialLogin { text-indent: -9999px; width: 40px; height: 40px; background-size: auto 40px; margin: 0 0 0 5px; } #cboxLoadedContent .registration-popup-message .lfcMembershipTable { clear: both; } #cboxLoadedContent .registration-popup-message .lfcMembershipTable th, #cboxLoadedContent .registration-popup-message .lfcMembershipTable td { float: left; width: 100%; } #cboxLoadedContent .registration-popup-message .lfcMembershipTable input { width: 100%; } #cboxLoadedContent .registration-popup-message .lfcMembershipTable th { text-align: left; } #cboxLoadedContent .registration-popup-message .lfcMembershipTable td.formHelp { text-align: right; padding: 5px 0; } #cboxLoadedContent .registration-popup-message .lfcMembershipTable tr.remember input { width: 19px; margin-right: 5px; } #cboxLoadedContent .registration-popup-message .lfcMembershipTable tr.remember td { text-align: left; }<style>';
#
# var regMessageHeaderMarkup = '<div class="richtext"> <h1>GET MORE FROM LFC</h1> <p class="small-content">Register or log in now to access <strong>FREE</strong> benefits</p> <p class="medium-content">Log in now, or register to access a range of <strong>FREE</strong> benefits including videos and exclusive competitions.</p> <p class="buttons"> <a href="javascript:void(0);" class="main-button close">No thanks</a> <a href="/my-lfc/join/user-details?user_type=free&source=audbuild" class="main-button">Yes, please!</a> </p></div>';
#
# var regMessageHeaderStyling = '<style> .header-message { background: #FFF; text-align: center; border-bottom: 2px solid #FFF; overflow: hidden; } .header-message::after { background: #C8C8C8; height: 6px; } .header-message > a.close { display: none; } .header-message .richtext a { text-decoration: none; } .header-message .buttons { margin: 10px 0; } .header-message .buttons a.main-button { margin: 0.2em 0.5em 0; padding: 0.8em 2em; } .header-message .buttons a.main-button.close { background: #FFF; color: #E31B23; border: 1px solid #E31B23; } .header-message p.medium-content { display: none; } @media screen and (min-width: 500px) { .header-message p.small-content { display: none; } .header-message p.medium-content { display: block; margin-bottom: 0; } .header-message .buttons { position: absolute; top: 0; right: 0; width: 11.5em; margin-bottom: 0; margin-right: 20px; } .header-message { min-height: 9em; } .header-message .richtext { margin-right: 14em; } .header-message .buttons a.main-button { display: block; margin: 0.6em 0; } }</style>';
#   </script>
#   <script type="text/javascript">
#    googletag.cmd.push(function() {
#
#   //general size mapping
#   var mapResMainRightOne = googletag.sizeMapping().
#    addSize([0, 0], [320, 50]).
#    addSize([500, 0], [486, 60]).
#    addSize([758, 0], [300, 250]).build();
#
#   var mapResMainRightTwo = googletag.sizeMapping().
#    addSize([0, 0], [320, 50]).
#    addSize([500, 0], [486, 60]).
#    addSize([758, 0], [300, 250]).build();
#
#
# 	 //general slots
# 		googletag.defineSlot('/87687331/RES_MAIN_RIGHT_ONE', [320, 50], 'div-gpt-ad-RES_MAIN_RIGHT_ONE').
# 				setTargeting("test","true").
# 				defineSizeMapping(mapResMainRightOne).
# 				addService(googletag.pubads());
#
# 		googletag.defineSlot('/87687331/RES_MAIN_RIGHT_TWO', [320, 50], 'div-gpt-ad-RES_MAIN_RIGHT_TWO').
# 				setTargeting("test","true").
# 				defineSizeMapping(mapResMainRightTwo).
# 				addService(googletag.pubads());
#
#   googletag.pubads().collapseEmptyDivs();
#   googletag.pubads().enableSingleRequest();
#   googletag.enableServices();
#  });
#   </script>
#   <style type="text/css">
#    .facebookButton{
# display:none!important;
# }
#   </style>
#  </head>
#  <body class="main-site-layout sonata-bc template-standard_two_column standard-two-column">
#   <!-- Google Tag Manager -->
#   <noscript>
#    <iframe height="0" src="//www.googletagmanager.com/ns.html?id=GTM-K2R8WV" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start': new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src='//www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);})(window,document,'script','dataLayer','GTM-K2R8WV');
#   </script>
#   <!-- End Google Tag Manager -->
#   <div class="wrapper">
#    <a id="page-top">
#    </a>
#    <header class="site-header" id="site-header" role="banner">
#     <div class="site-header-inner">
#      <div class="masthead">
#       <ul class="account-links logged-out-only">
#        <li class="subnav">
#         <a>
#          Log In
#         </a>
#         <ul>
#          <li class=" link-login first">
#           <a href="/my-lfc/login" target="">
#            My LFC
#           </a>
#          </li>
#          <li class=" ">
#           <a href="https://tickets.liverpoolfc.com/PagesLogin/Profile/myAccount.aspx" target="">
#            Tickets
#           </a>
#          </li>
#          <li class=" ">
#           <a href="https://store.liverpoolfc.com/customer/account/login/" target="">
#            Online Store
#           </a>
#          </li>
#          <li class=" ">
#           <a href="https://members.liverpoolfc.com/login" target="">
#            Membership
#           </a>
#          </li>
#          <li class=" ">
#           <a href="/my-lfc/login?fragment=&amp;referer=http://www.liverpoolfc.com/video" target="">
#            LFCTV GO
#           </a>
#          </li>
#          <li class=" separator last">
#           <a href="http://www.liverpoolfc.com/loginhelp" target="">
#            Not sure?
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class="link-separator">
#        </li>
#        <li class="subnav">
#         <a>
#          Register
#         </a>
#         <ul>
#          <li class=" first">
#           <a href="/my-lfc/join/user-details?user_type=free" target="">
#            Free Registration
#           </a>
#          </li>
#          <li class=" ">
#           <a href="/tickets" target="">
#            Tickets
#           </a>
#          </li>
#          <li class=" ">
#           <a href="https://store.liverpoolfc.com/customer/account/login/" target="">
#            Online Store
#           </a>
#          </li>
#          <li class=" ">
#           <a href="/membership" target="">
#            Join Membership
#           </a>
#          </li>
#          <li class=" ">
#           <a href="/my-lfc/join/user-details?user_type=lfctvo" target="">
#            Join LFCTV GO
#           </a>
#          </li>
#          <li class=" separator last">
#           <a href="http://www.liverpoolfc.com/loginhelp" target="">
#            Not Sure?
#           </a>
#          </li>
#         </ul>
#        </li>
#       </ul>
#       <ul class="account-links logged-in-only">
#        <li>
#         <a class="link-logout" href="https://www.liverpoolfc.com/scripts/logout.php" title="Logout">
#          Log out
#         </a>
#        </li>
#        <li class="link-separator">
#        </li>
#        <li>
#         <a class="link-my-lfc" href="https://www.liverpoolfc.com/my-lfc" title="My LFC">
#          My LFC
#         </a>
#        </li>
#       </ul>
#       <div class="masthead-links" id="masthead-links">
#        <ul class="more-menu ">
#         <li class="more-menu-link">
#          <a>
#           More
#          </a>
#          <ul>
#           <li class=" first">
#            <a href="https://video.liverpoolfc.com/" target="">
#             LFCTV GO
#            </a>
#           </li>
#           <li class=" ">
#            <a href="http://hospitality.liverpoolfc.com" target="">
#             MATCH HOSPITALITY
#            </a>
#           </li>
#           <li class="bp-min-large-more-min-xlarge-primary ">
#            <a href="http://www.liverpoolfc.com/membership/home" target="">
#             MEMBERSHIP
#            </a>
#           </li>
#           <li class=" ">
#            <a href="http://foundation.liverpoolfc.com" target="">
#             FOUNDATION
#            </a>
#           </li>
#           <li class=" ">
#            <a href="http://stadiumtours.liverpoolfc.com">
#             STADIUM TOURS
#            </a>
#           </li>
#           <li class="bp-more-only ">
#            <a href="http://events.liverpoolfc.com" target="">
#             MEETING &amp; EVENTS
#            </a>
#           </li>
#           <li class=" ">
#            <a href="http://soccerschools.liverpoolfc.com">
#             SOCCER SCHOOLS
#            </a>
#           </li>
#           <li class="bp-more-only ">
#            <a href="http://www.liverpoolfc.com/kopkids">
#             KOP KIDS
#            </a>
#           </li>
#           <li class="bp-more-only ">
#            <a href="http://store.liverpoolfc.com">
#             SHOP
#            </a>
#           </li>
#           <li class="bp-more-only ">
#            <a href="http://bootroom.liverpoolfc.com">
#             BOOT ROOM
#            </a>
#           </li>
#           <li class="bp-more-only last">
#            <a href="http://www.liverpoolfc.com/lfcevents" target="">
#             LFC EVENTS
#            </a>
#           </li>
#          </ul>
#         </li>
#        </ul>
#        <ul>
#         <li class=" first">
#          <a href="https://video.liverpoolfc.com/" target="">
#           LFCTV GO
#          </a>
#         </li>
#         <li class=" ">
#          <a href="http://hospitality.liverpoolfc.com" target="">
#           MATCH HOSPITALITY
#          </a>
#         </li>
#         <li class="bp-min-large-more-min-xlarge-primary ">
#          <a href="http://www.liverpoolfc.com/membership/home" target="">
#           MEMBERSHIP
#          </a>
#         </li>
#         <li class=" ">
#          <a href="http://foundation.liverpoolfc.com" target="">
#           FOUNDATION
#          </a>
#         </li>
#         <li class=" ">
#          <a href="http://stadiumtours.liverpoolfc.com">
#           STADIUM TOURS
#          </a>
#         </li>
#         <li class="bp-more-only ">
#          <a href="http://events.liverpoolfc.com" target="">
#           MEETING &amp; EVENTS
#          </a>
#         </li>
#         <li class=" ">
#          <a href="http://soccerschools.liverpoolfc.com">
#           SOCCER SCHOOLS
#          </a>
#         </li>
#         <li class="bp-more-only ">
#          <a href="http://www.liverpoolfc.com/kopkids">
#           KOP KIDS
#          </a>
#         </li>
#         <li class="bp-more-only ">
#          <a href="http://store.liverpoolfc.com">
#           SHOP
#          </a>
#         </li>
#         <li class="bp-more-only ">
#          <a href="http://bootroom.liverpoolfc.com">
#           BOOT ROOM
#          </a>
#         </li>
#         <li class="bp-more-only last">
#          <a href="http://www.liverpoolfc.com/lfcevents" target="">
#           LFC EVENTS
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#      <div class="logo">
#       <a class="logo-large" href="/" title="Home">
#        <img alt="Liverpool FC" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-271/lfc/images/logo.png"/>
#       </a>
#       <a class="logo-medium" href="/" title="Home">
#        <img alt="Liverpool FC" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-271/lfc/images/logo.png"/>
#       </a>
#       <a class="logo-small" href="/" title="Home">
#        <img alt="Liverpool FC" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-271/lfc/images/logo-small.png"/>
#       </a>
#      </div>
#      <a class="sponsor" href="//www.sc.com/en/" target="main-sponsor">
#       Main Club Sponsor: Standard Chartered
#      </a>
#      <div class="search">
#      </div>
#      <nav class="main-menu">
#       <ul>
#        <li class=" active-home first">
#         <a href="/" target="">
#          HOME
#         </a>
#        </li>
#        <li class="bp-medium-more-only log-out-menu-link">
#         <a href="/scripts/logout.php" target="">
#          LOG OUT
#         </a>
#        </li>
#        <li class=" active-news">
#         <a href="https://www.liverpoolfc.com/news" target="">
#          NEWS
#         </a>
#         <ul class="menu_level_1">
#          <li class=" first">
#           <a href="https://www.liverpoolfc.com/news/first-team" target="">
#            First Team
#           </a>
#          </li>
#          <li class=" ">
#           <a href="https://www.liverpoolfc.com/news/tickets" target="">
#            Ticket News
#           </a>
#          </li>
#          <li class=" ">
#           <a href="https://www.liverpoolfc.com/news/media-watch" target="">
#            Media Watch
#           </a>
#          </li>
#          <li class=" ">
#           <a href="https://www.liverpoolfc.com/news/community" target="">
#            Community
#           </a>
#          </li>
#          <li class=" ">
#           <a href="https://www.liverpoolfc.com/news/announcements" target="">
#            Announcements
#           </a>
#          </li>
#          <li class=" ">
#           <a href="https://www.liverpoolfc.com/lfctv" target="">
#            LFCTV - WHAT'S ON
#           </a>
#          </li>
#          <li class=" ">
#           <a href="https://www.liverpoolfc.com/hillsborough" target="_blank">
#            Hillsborough
#           </a>
#          </li>
#          <li class=" ">
#           <a href="https://www.liverpoolfc.com/news/training-ground" target="">
#            Training Ground
#           </a>
#          </li>
#          <li class=" last">
#           <a href="https://nesn.com/liverpool-fc/" target="_blank">
#            LFC on NESN
#           </a>
#          </li>
#         </ul>
#        </li>
#        <li class=" ">
#         <a href="https://www.liverpoolfc.com/match" target="">
#          MATCH
#         </a>
#         <ul class="menu_level_1">
#          <li class=" first">
#           <a href="https://www.liverpoolfc.com/match/2018-19/first-team/fixtures-and-results" target="">
#            Fixtures and Results
#           </a>
#          </li>
#          <li class=" ">
#           <a href="https://www.liverpoolfc.com/match/2018-19/premier-league-table" target="">
#            League Table
#           </a>
#          </li>
#          <li class=" ">
#           <a href="https://www.liverpoolfc.com
#             </a>
#            </li>
#            <li class=" ">
#             <a href="https://www.liverpoolfc.com/match/2018-19/full-premier-league-fixtures-listing" target="">
#              PL Calendar
#             </a>
#            </li>
#            <li class=" ">
#             <a href="http://women.liverpoolfc.com/index.html" target="_blank">
#              Liverpool FC Women
#             </a>
#            </li>
#            <li class=" ">
#             <a href="https://www.liverpoolfc.com/match/2018-19/under-23s/fixtures-and-results" target="">
#              U23S
#             </a>
#            </li>
#            <li class=" ">
#             <a href="https://www.liverpoolfc.com/match/2018-19/under-18s/fixtures-and-results" target="">
#              U18S
#             </a>
#            </li>
#            <li class=" ">
#             <a href="https://www.liverpoolfc.com/match/opta-stats/team-stats" target="">
#              Opta Stats
#             </a>
#            </li>
#            <li class=" ">
#             <a href="https://sportmediashop.com/team/liverpool/" target="_blank">
#              Programme and Magazine
#             </a>
#            </li>
#            <li class=" last">
#             <a href="https://www.liverpoolfc.com/fans/apps-and-games/uk" target="">
#              App Match Notifications
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class=" ">
#           <a href="https://www.liverpoolfc.com/tickets/tickets-availability" target="">
#            TICKETS
#           </a>
#           <ul class="menu_level_1">
#            <li class=" first">
#             <a href="https://www.liverpoolfc.com/fans/away-travel" target="">
#              Away Travel
#             </a>
#            </li>
#            <li class=" ">
#             <a href="https://hospitality.liverpoolfc.com/" target="_blank">
#              Match Hospitality
#             </a>
#            </li>
#            <li class=" ">
#             <a href="https://www.liverpoolfc.com/lfcevents" target="">
#              LFC EVENTS
#             </a>
#            </li>
#            <li class=" last">
#             <a href="https://www.liverpoolfc.com/tickets/how-to-buy-tickets" target="">
#              HOW TO BUY TICKETS
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class=" ">
#           <a href="https://www.liverpoolfc.com/team/first-team" target="">
#            TEAM
#           </a>
#           <ul class="menu_level_1">
#            <li class=" first">
#             <a href="https://www.liverpoolfc.com/team/first-team" target="">
#              First Team
#             </a>
#            </li>
#            <li class=" ">
#             <a href="http://women.liverpoolfc.com/index.html" target="_blank">
#              Women
#             </a>
#            </li>
#            <li class=" last">
#             <a href="https://www.liverpoolfc.com/team/academy" target="">
#              Academy
#             </a>
#            </li>
#           </ul>
#          </li>
#          <li class="bp-medium-more-min-large-primary ">
#           <a href="https://www.liverpoolfc.com/fans/fan-experience/visiting-anfield" target="">
#            ANFIELD
#           </a>
#           <ul class="menu_level_1">
#            <li class="bp-medium-more-min-large-primary first">
#             <a href="https://www.liverpoolfc.com/fans/fan-experience/visiting-anfield" target="">
#              Visiting Anfield
#             </a>
#            </li>
#            <li class="bp-medium-more-min-large-primary ">
#             <a href="https://www.liverpoolfc.com/fans/fan-experience/getting-to-anfield" target="">
#              Getting to Anfield
#             </a>
#            </li>
#            <li class=" ">
#             <a href="https://www.liverpoolfc.com/fans/fan-experience/fan-zones" target="">
#              Fan Zones
#             </a>
#            </li>
#            <li class=" ">
#             <a href="https://stadiumtours.liverpoolfc.com/" target="_blank">
#              Stadium Tours
#             </a>
#            </li>
#            <li class=" ">
#             <a href="https://events.liverpoolfc.com/" target="_blank">
# ...
#                53
#               </div>
#               <div class="about">
#                <div class="name">
#                 <span>
#                  Ovie
#                 </span>
#                 <span>
#                  Ejaria
#                 </span>
#                </div>
#               </div>
#              </a>
#             </li>
#             <li class="team-player-list-item">
#              <a href="/team/first-team/player/sheyi-ojo">
#               <div class="img-wrap">
#                <img alt="Sheyi Ojo" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/26/thumb_25355_misc_general_500.jpeg"/>
#               </div>
#               <div class="number">
#                54
#               </div>
#               <div class="about">
#                <div class="name">
#                 <span>
#                  Sheyi
#                 </span>
#                 <span>
#                  Ojo
#                 </span>
#                </div>
#               </div>
#              </a>
#             </li>
#             <li class="team-player-list-item">
#              <a href="/team/first-team/player/harry-wilson">
#               <div class="img-wrap">
#                <img alt="Harry Wilson" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/50/thumb_49324_misc_general_500.jpeg"/>
#               </div>
#               <div class="number">
#                59
#               </div>
#               <div class="about">
#                <div class="name">
#                 <span>
#                  Harry
#                 </span>
#                 <span>
#                  Wilson
#                 </span>
#                </div>
#               </div>
#              </a>
#             </li>
#             <li class="team-player-list-item">
#              <a href="/team/first-team/player/pedro-chirivella">
#               <div class="img-wrap">
#                <img alt="Pedro Chirivella" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/26/thumb_25335_misc_general_500.jpeg"/>
#               </div>
#               <div class="number">
#                68
#               </div>
#               <div class="about">
#                <div class="name">
#                 <span>
#                  Pedro
#                 </span>
#                 <span>
#                  Chirivella
#                 </span>
#                </div>
#               </div>
#              </a>
#             </li>
#             <li class="team-player-list-item">
#              <a href="/team/first-team/player/kamil-grabara">
#               <div class="img-wrap">
#                <img alt="Kamil Grabara" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69964_misc_general_500.jpeg"/>
#               </div>
#               <div class="number">
#                73
#               </div>
#               <div class="about">
#                <div class="name">
#                 <span>
#                  Kamil
#                 </span>
#                 <span>
#                  Grabara
#                 </span>
#                </div>
#               </div>
#              </a>
#             </li>
#             <li class="team-player-list-item">
#              <a href="/team/first-team/player/allan">
#               <div class="img-wrap">
#                <img alt="Allan" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/24/thumb_23741_misc_general_500.jpeg"/>
#               </div>
#               <div class="number">
#               </div>
#               <div class="about">
#                <div class="name">
#                 <span>
#                  Allan
#                 </span>
#                </div>
#               </div>
#              </a>
#             </li>
#             <li class="team-player-list-item">
#              <a href="/team/first-team/player/taiwo-awoniyi">
#               <div class="img-wrap">
#                <img alt="Taiwo Awoniyi" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/69/thumb_68336_misc_general_500.jpeg"/>
#               </div>
#               <div class="number">
#               </div>
#               <div class="about">
#                <div class="name">
#                 <span>
#                  Taiwo
#                 </span>
#                 <span>
#                  Awoniyi
#                 </span>
#                </div>
#               </div>
#              </a>
#             </li>
#            </ul>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="cms-block cms-block-element" data-block-type="sonata.page.block.container" id="cms-block-3194">
#         <div class="container-block block-3194 ">
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="rightCol">
#       <div class="rightAd">
#        <div id="div-gpt-ad-RES_MAIN_RIGHT_ONE">
#         <script>
#          Lfc.gtmAdQueue.push('div-gpt-ad-RES_MAIN_RIGHT_ONE');
#         </script>
#        </div>
#       </div>
#       <div class="cms-block cms-block-element" data-block-type="sonata.page.block.container" id="cms-block-2919">
#        <div class="container-block block-2919 ">
#         <div class="cms-block cms-block-element" data-block-type="sonata.block.service.text" id="cms-block-3332">
#          <style type="text/css">
#           .richtext.linkList a {
#         display: block;
#         padding: 6px;
#         margin-bottom: 0;
#         overflow: hidden;
#         padding-right: 30px;
#         position: relative;
#         color: #333;
#         font-weight: normal;
#     }
#
#     .richtext.linkList a:nth-child(odd) {
#         background: #F6F6F6;
#     }
#
#     .richtext.linkList a:after {
#         border-bottom: 8px solid transparent;
#         border-left: 12px solid #E31B23;
#         border-top: 8px solid transparent;
#         content: "";
#         display: inline-block;
#         height: 0;
#         position: absolute;
#         width: 0;
#         right: 10px;
#         margin-top: -8px;
#         top: 50%;
#     }
#
# @media screen and (max-width: 699px){
# .mainColInner .richtext img {
# width: 100%!important;
# height: auto!important;
# float: left!important;
# margin-bottom: 30px!important;
# }
#          </style>
#          <div class="richtext linkList">
#           <h2>
#            First Team Staff
#           </h2>
#           <a href="/team/first-team/staff/jurgen-klopp">
#            Jürgen Klopp
#           </a>
#           <a href="/team/first-team/staff/peter-krawietz">
#            Peter Krawietz
#           </a>
#           <a href="/team/first-team/staff/pepijn-lijnders">
#            Pepijn Lijnders
#           </a>
#           <a href="/team/first-team/staff/john-achterberg">
#            John Achterberg
#           </a>
#           <a href="/team/first-team/staff/jack-robinson">
#            Jack Robinson
#           </a>
#           <a href="/team/first-team/staff/andreas-kornmayer">
#            Andreas Kornmayer
#           </a>
#           <a href="/team/first-team/staff/andrew-massey">
#            Andrew Massey
#           </a>
#           <a href="/team/first-team/staff/philipp-jacobsen">
#            Philipp Jacobsen
#           </a>
#           <a href="/team/first-team/staff/conall-murtagh">
#            Conall Murtagh
#           </a>
#           <a href="/team/first-team/staff/paul-small">
#            Paul Small
#           </a>
#           <a href="/team/first-team/staff/lee-radcliffe">
#            Lee Radcliffe
#           </a>
#           <a href="/team/first-team/staff/graham-carter">
#            Graham Carter
#           </a>
#           <a href="/team/first-team/staff/david-rydings">
#            David Rydings
#           </a>
#           <a href="/team/first-team/staff/mona-nemmer">
#            Mona Nemmer
#           </a>
#           <a href="/team/first-team/staff/mark-leyland">
#            Mark Leyland
#           </a>
#           <a href="/team/first-team/staff/greg-mathieson">
#            Greg Mathieson
#           </a>
#           <a href="/team/first-team/staff/james-french">
#            James French
#           </a>
#           <a href="/team/first-team/staff/scott-mcauley">
#            Scott McAuley
#           </a>
#           <a href="/team/first-team/staff/christopher-rohrbeck">
#            Christopher Rohrbeck
#           </a>
#           <a href="/team/first-team/staff/richie-partridge">
#            Richie Partridge
#           </a>
#           <a href="/team/first-team/staff/joe-lewis">
#            Joe Lewis
#           </a>
#          </div>
#         </div>
#         <div class="cms-block cms-block-element" data-block-type="lfc.opta.standings.block.service" id="cms-block-3333">
#          <section class="opta-wrapper" id="league-table">
#           <opta competition="8" live="true" season="2018" show_image="false" show_layout="full" sorting="false" sport="football" team="14" team_name="normal" widget="standings">
#           </opta>
#          </section>
#         </div>
#        </div>
#       </div>
#       <div class="rightAd">
#        <div id="div-gpt-ad-RES_MAIN_RIGHT_TWO">
#         <script>
#          Lfc.gtmAdQueue.push('div-gpt-ad-RES_MAIN_RIGHT_TWO');
#         </script>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <footer id="page-footer">
#     <div class="upperBackground">
#      <section class="partners">
#       <div class="Primary">
#        <a href="http://www.standardchartered.com/home/en/index.html?camp_id=liverpool_source=liverpoolfctv_medium=4" target="_blank" title="Standard Chartered">
#         <img alt="Standard Chartered" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0001/16/thumb_15152_partnerlogo_partner_footer.png"/>
#        </a>
#        <a href="https://www.newbalance.co.uk/liverpool/?searchSource=liverpool" target="_blank" title="New Balance">
#         <img alt="New Balance" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0001/01/thumb_46_partnerlogo_partner_footer.png"/>
#        </a>
#       </div>
#       <div class="Secondary">
#        <a href="https://www.westernunion.com/sponsorships/lfc/?src=lfc_landingwebsitelogo" target="_blank" title="Western Union">
#         <img alt="Western Union" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0001/83/thumb_82160_partnerlogo_partner_footer.png"/>
#        </a>
#       </div>
#       <div class="Tertiary">
#        <a href="https://www.axa.com/?utm_source=liverpoolfc&amp;utm_medium=logo-partnership&amp;utm_campaign=lfc1819season" target="_blank" title="AXA">
#         <img alt="AXA" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0001/74/thumb_73714_partnerlogo_partner_footer.png"/>
#        </a>
#        <a href="http://www.carlsberg.com/" target="_blank" title="Carlsberg">
#         <img alt="Carlsberg" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0001/47/thumb_46751_partnerlogo_partner_footer.png"/>
#        </a>
#        <a href="http://www.malaysiaairlines.com/" target="_blank" title="Malaysia AirLines">
#         <img alt="Malaysia AirLines" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0001/29/thumb_28469_partnerlogo_partner_footer.png"/>
#        </a>
#        <a href="http://www.falken.tires/" target="_blank" title="Falken Tyres">
#         <img alt="Falken Tyres" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0001/45/thumb_44469_partnerlogo_partner_footer.jpeg"/>
#        </a>
#        <a href="https://global.tigerwit.com/web/aboutus/liverpool" target="_blank" title="TigerWit">
#         <img alt="TigerWit" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0001/73/thumb_72810_partnerlogo_partner_footer.png"/>
#        </a>
#        <a href="https://nordvpn.com/LFC" target="_blank" title="NordVPN">
#         <img alt="NordVPN" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0001/78/thumb_77003_partnerlogo_partner_footer.png"/>
#        </a>
#        <a href="http://www.tcc-chaokoh.com/" target="_blank" title="Chaokoh">
#         <img alt="Chaokoh" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0001/28/thumb_27835_partnerlogo_partner_footer.png"/>
#        </a>
#        <a href="https://www.konami.com/wepes/2019/eu/en/" target="_blank" title="Konami">
#         <img alt="Konami" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0001/73/thumb_72809_partnerlogo_partner_footer.png"/>
#        </a>
#        <a href="https://www.nipponham.co.jp/eng/" target="_blank" title="NH Foods">
#         <img alt="NH Foods" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0001/86/thumb_85085_partnerlogo_partner_footer.png"/>
#        </a>
#        <a href="https://store.liverpoolfc.com/baby-strollers-car-seats/" target="_blank" title="Joie Baby">
#         <img alt="Joie Baby" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0001/41/thumb_40979_partnerlogo_partner_footer.png"/>
#        </a>
#        <a href="https://lubricants.petro-canada.com" target="_blank" title="Petro-Canada">
#         <img alt="Petro-Canada" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0001/58/thumb_57374_partnerlogo_partner_footer.png"/>
#        </a>
#        <a href="https://www.mitel.com/learn/case-studies/liverpool-football-club" target="_blank" title="Mitel">
#         <img alt="Mitel" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/partnerlogo/0001/78/thumb_77004_partnerlogo_partner_footer.png"/>
#        </a>
#       </div>
#      </section>
#     </div>
#     <div class="lowerBackground">
#      <section class="bottomFooter">
#       <div class="footerCrest">
#       </div>
#       <div class="footerCrestLeft">
#       </div>
#       <div class="footerText">
#        <div class="footer-middleBottom">
#         <a href="http://www.liverpoolfc.com/legal/privacy-policy" title="Go to Privacy Policy">
#          Privacy Policy
#         </a>
#         <span>
#          |
#         </span>
#         <a href="http://www.liverpoolfc.com/legal/terms-and-conditions" title="Go to Terms and Conditions">
#          Terms and Conditions
#         </a>
#         <span>
#          |
#         </span>
#         <a href="http://www.liverpoolfc.com/corporate/anti-slavery" title="Go to Anti-Slavery">
#          Anti-Slavery
#         </a>
#         <span>
#          |
#         </span>
#         <a href="http://www.liverpoolfc.com/legal/cookies" title="Go to Cookies">
#          Cookies
#         </a>
#         <span>
#          |
#         </span>
#         <a href="https://help.liverpoolfc.com/" title="Go to Help">
#          Help
#         </a>
#         <span>
#          |
#         </span>
#         <a href="http://www.liverpoolfc.com/corporate/browser-support" title="Go to Browser Support">
#          Browser Support
#         </a>
#         <span>
#          |
#         </span>
#         <a href="http://www.liverpoolfc.com/corporate/rss-feeds" title="Go to RSS Feeds">
#          RSS Feeds
#         </a>
#         <span>
#          |
#         </span>
#         <a href="http://www.liverpoolfc.com/contactus" title="Go to Contact Us">
#          Contact Us
#         </a>
#         <span>
#          |
#         </span>
#         <a href="http://www.liverpoolfc.com/accessible/accessible" title="Go to Accessibility">
#          Accessibility
#         </a>
#         <br/>
#        </div>
#        <div class="footer-left">
#         © Copyright 2019 The Liverpool Football Club and Athletic Grounds Limited. All rights reserved.
#        </div>
#        <div class="footer-right">
#         Developed and maintained by the LFC Technology and Transformation Team
#        </div>
#        <div class="footer-middle">
#         Match Statistics supplied by Opta Sports Data Limited. Reproduced under licence from Football DataCo Limited. All rights reserved.
#        </div>
#       </div>
#      </section>
#     </div>
#    </footer>
#   </div>
#   <script src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/JE-271/lfc/js/scripts.min.js">
#   </script>
#   <script src="https://secure.widget.cloud.opta.net/2.0/js/widgets.opta.js">
#   </script>
#   <script>
#    _optaParams = {
#             custID:             'da747e372c352a82f3dd6174084858fd',
#             language:           'en',
#             suppressAnalytics:  true
#         };
#   </script>
#   <style>
#    .team-player-list-item .name > span {
# width:40px;
# }
#   </style>
#   <!-- monitoring:3e9fda56df2cdd3b039f189693ab7844fbb2d4f6 -->
#  </body>
# </html>

# %%
players = s.find_all('li',{'class':'team-player-list-item'})
len(players)
# Out:
# 41

# %%
print(players[1].prettify())
# Out:
# <li class="team-player-list-item">
#  <a href="/team/first-team/player/simon-mignolet">
#   <div class="img-wrap">
#    <img alt="Simon Mignolet" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69999_misc_general_500.jpeg"/>
#   </div>
#   <div class="number">
#    22
#   </div>
#   <div class="about">
#    <div class="name">
#     <span>
#      Simon
#     </span>
#     <span>
#      Mignolet
#     </span>
#    </div>
#   </div>
#  </a>
# </li>

# %%
players[0].find('a')['href']
# Out:
# '/team/first-team/player/alisson-becker'

# %%
players[0].find('div',{'class' : 'number'})
# Out:
# <div class="number">13</div>

# %%
players[0].find('div',{'class' : 'number'}).text
# Out:
# '13'

# %%
players[0].find('div',{'class':'name'}).find_all('span')[0]
# Out:
# <span>Alisson</span>

# %%
players[0].find('div',{'class':'name'}).find_all('span')[0].text
# Out:
# 'Alisson'

# %%
print(players[0].prettify())
# Out:
# <li class="team-player-list-item">
#  <a href="/team/first-team/player/alisson-becker">
#   <div class="img-wrap">
#    <img alt="Alisson Becker" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69945_misc_general_500.jpeg"/>
#   </div>
#   <div class="number">
#    13
#   </div>
#   <div class="about">
#    <div class="name">
#     <span>
#      Alisson
#     </span>
#     <span>
#      Becker
#     </span>
#    </div>
#   </div>
#  </a>
# </li>

# %%
players[0].find('img')
# Out:
# <img alt="Alisson Becker" src="https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69945_misc_general_500.jpeg"/>

# %%
type(players[0].find('img'))
# Out:
# bs4.element.Tag

# %%
players[0].find('img')['alt']
# Out:
# 'Alisson Becker'

# %%
players[0].find('img')['src']
# Out:
# 'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69945_misc_general_500.jpeg'

# %%
r1 = requests.get(players[0].find('img')['src'])
img = Image.open(io.BytesIO(r1.content))
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=263x263 at 0x1FC8D2254E0>

# %%
lst = []
for e in players:
    mem_img_url = e.find('img')['src']
    mem_name = e.find('img')['alt']
    mem_number = e.find('div',{'class' : 'number'}).text
    mem_link = f"https://www.liverpoolfc.com{e.find('a')['href']}"
    print(f'{mem_name} {mem_number} {mem_img_url} {mem_link}')
    lst.append([mem_name, mem_number, mem_img_url, mem_link])
    
lst
# Out:
# Alisson Becker 13 https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69945_misc_general_500.jpeg https://www.liverpoolfc.com/team/first-team/player/alisson-becker
# Simon Mignolet 22 https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69999_misc_general_500.jpeg https://www.liverpoolfc.com/team/first-team/player/simon-mignolet
# Caoimhin Kelleher 62 https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69996_misc_general_500.jpeg https://www.liverpoolfc.com/team/first-team/player/caoimhin-kelleher
# Virgil van Dijk 4 https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/71/thumb_70012_misc_general_500.jpeg https://www.liverpoolfc.com/team/first-team/player/virgil-van-dijk
# Dejan Lovren 6 https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/72/thumb_71690_misc_general_500.jpeg https://www.liverpoolfc.com/team/first-team/player/dejan-lovren
# Joe Gomez 12 https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69956_misc_general_500.jpeg https://www.liverpoolfc.com/team/first-team/player/joe-gomez
# Alberto Moreno 18 https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/72/thumb_71692_misc_general_500.jpeg https://www.liverpoolfc.com/team/first-team/player/alberto-moreno
# Andy Robertson 26 https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/71/thumb_70006_misc_general_500.jpeg https://www.liverpoolfc.com/team/first-team/player/andy-robertson
# Joel Matip 32 https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69998_misc_general_500.jpeg https://www.liverpoolfc.com/team/first-team/player/joel-matip
# Nathaniel Phillips 47 https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/71/thumb_70005_misc_general_500.jpeg https://www.liverpoolfc.com/team/first-team/player/nathaniel-phillips
# Trent Alexander-Arnold 66 https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/71/thumb_70011_misc_general_500.jpeg https://www.liverpoolfc.com/team/first-team/player/trent-alexander-arnold
# Fabinho 3 https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69953_misc_general_500.jpeg https://www.liverpoolfc.com/team/first-team/player/fabinho
# Georginio Wijnaldum 5 https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/71/thumb_70013_misc_general_500.jpeg https://www.liverpoolfc.com/team/first-team/player/georginio-wijnaldum
# James Milner 7 https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/72/thumb_71691_misc_general_500.jpeg https://www.liverpoolfc.com/team/first-team/player/james-milner
# Naby Keita 8 https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69990_misc_general_500.jpeg https://www.liverpoolfc.com/team/first-team/player/naby-keita
# Jordan Henderson 14 https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69958_misc_general_500.jpeg https://www.liverpoolfc.com/team/first-team/player/jordan-henderson
# Adam Lallana 20 https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/72/thumb_71689_misc_general_500.jpeg https://www.liverpoolfc.com/team/first-team/player/adam-lallana
# Alex Oxlade-Chamberlain 21 https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/72/thumb_71693_misc_general_500.jpeg https://www.liverpoolfc.com/team/first-team/player/alex-oxlade-chamberlain
# Xherdan Shaqiri 23 https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/71/thumb_70009_misc_general_500.jpeg https://www.liverpoolfc.com/team/first-team/player/xherdan-shaqiri
# Curtis Jones 48 https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69988_misc_general_500.jpeg https://www.liverpoolfc.com/team/first-team/player/curtis-jones
# Ben Woodburn 58 https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/50/thumb_49325_misc_general_500.jpeg https://www.liverpoolfc.com/team/first-team/player/ben-woodburn
# Rafael Camacho 64 https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69949_misc_general_500.jpeg https://www.liverpoolfc.com/team/first-team/player/rafael-camacho
# Roberto Firmino 9 https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69955_misc_general_500.jpeg https://www.liverpoolfc.com/team/first-team/player/roberto-firmino
# Sadio Mane 10 https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69997_misc_general_500.jpeg https://www.liverpoolfc.com/team/first-team/player/sadio-mane
# Mohamed Salah 11 https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/71/thumb_70007_misc_general_500.jpeg https://www.liverpoolfc.com/team/first-team/player/mohamed-salah
# Daniel Sturridge 15 https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/71/thumb_70010_misc_general_500.jpeg https://www.liverpoolfc.com/team/first-team/player/daniel-sturridge
# Rhian Brewster 24 https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/72/thumb_71688_misc_general_500.jpeg https://www.liverpoolfc.com/team/first-team/player/rhian-brewster
# Divock Origi 27 https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/71/thumb_70001_misc_general_500.jpeg https://www.liverpoolfc.com/team/first-team/player/divock-origi
# Loris Karius 1 https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69989_misc_general_500.jpeg https://www.liverpoolfc.com/team/first-team/player/loris-karius
# Nathaniel Clyne 2 https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69952_misc_general_500.jpeg https://www.liverpoolfc.com/team/first-team/player/nathaniel-clyne
# Marko Grujic 16 https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69957_misc_general_500.jpeg https://www.liverpoolfc.com/team/first-team/player/marko-grujic
# Danny Ings 28 https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69959_misc_general_500.jpeg https://www.liverpoolfc.com/team/first-team/player/danny-ings
# Adam Bogdan 34 https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/50/thumb_49294_misc_general_500.jpeg https://www.liverpoolfc.com/team/first-team/player/adam-bogdan
# Ryan Kent 40 https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/50/thumb_49306_misc_general_500.jpeg https://www.liverpoolfc.com/team/first-team/player/ryan-kent
# Ovie Ejaria 53 https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/50/thumb_49298_misc_general_500.jpeg https://www.liverpoolfc.com/team/first-team/player/ovie-ejaria
# Sheyi Ojo 54 https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/26/thumb_25355_misc_general_500.jpeg https://www.liverpoolfc.com/team/first-team/player/sheyi-ojo
# Harry Wilson 59 https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/50/thumb_49324_misc_general_500.jpeg https://www.liverpoolfc.com/team/first-team/player/harry-wilson
# Pedro Chirivella 68 https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/26/thumb_25335_misc_general_500.jpeg https://www.liverpoolfc.com/team/first-team/player/pedro-chirivella
# Kamil Grabara 73 https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69964_misc_general_500.jpeg https://www.liverpoolfc.com/team/first-team/player/kamil-grabara
# Allan  https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/24/thumb_23741_misc_general_500.jpeg https://www.liverpoolfc.com/team/first-team/player/allan
# Taiwo Awoniyi  https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/69/thumb_68336_misc_general_500.jpeg https://www.liverpoolfc.com/team/first-team/player/taiwo-awoniyi
# [['Alisson Becker',
#   '13',
#   'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69945_misc_general_500.jpeg',
#   'https://www.liverpoolfc.com/team/first-team/player/alisson-becker'],
#  ['Simon Mignolet',
#   '22',
#   'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69999_misc_general_500.jpeg',
#   'https://www.liverpoolfc.com/team/first-team/player/simon-mignolet'],
#  ['Caoimhin Kelleher',
#   '62',
#   'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69996_misc_general_500.jpeg',
#   'https://www.liverpoolfc.com/team/first-team/player/caoimhin-kelleher'],
#  ['Virgil van Dijk',
#   '4',
#   'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/71/thumb_70012_misc_general_500.jpeg',
#   'https://www.liverpoolfc.com/team/first-team/player/virgil-van-dijk'],
#  ['Dejan Lovren',
#   '6',
#   'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/72/thumb_71690_misc_general_500.jpeg',
#   'https://www.liverpoolfc.com/team/first-team/player/dejan-lovren'],
#  ['Joe Gomez',
#   '12',
#   'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69956_misc_general_500.jpeg',
#   'https://www.liverpoolfc.com/team/first-team/player/joe-gomez'],
#  ['Alberto Moreno',
#   '18',
#   'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/72/thumb_71692_misc_general_500.jpeg',
#   'https://www.liverpoolfc.com/team/first-team/player/alberto-moreno'],
#  ['Andy Robertson',
#   '26',
#   'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/71/thumb_70006_misc_general_500.jpeg',
#   'https://www.liverpoolfc.com/team/first-team/player/andy-robertson'],
#  ['Joel Matip',
#   '32',
#   'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69998_misc_general_500.jpeg',
#   'https://www.liverpoolfc.com/team/first-team/player/joel-matip'],
#  ['Nathaniel Phillips',
#   '47',
#   'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/71/thumb_70005_misc_general_500.jpeg',
#   'https://www.liverpoolfc.com/team/first-team/player/nathaniel-phillips'],
#  ['Trent Alexander-Arnold',
#   '66',
#   'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/71/thumb_70011_misc_general_500.jpeg',
#   'https://www.liverpoolfc.com/team/first-team/player/trent-alexander-arnold'],
#  ['Fabinho',
#   '3',
#   'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69953_misc_general_500.jpeg',
#   'https://www.liverpoolfc.com/team/first-team/player/fabinho'],
#  ['Georginio Wijnaldum',
#   '5',
#   'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/71/thumb_70013_misc_general_500.jpeg',
#   'https://www.liverpoolfc.com/team/first-team/player/georginio-wijnaldum'],
#  ['James Milner',
#   '7',
#   'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/72/thumb_71691_misc_general_500.jpeg',
#   'https://www.liverpoolfc.com/team/first-team/player/james-milner'],
#  ['Naby Keita',
#   '8',
#   'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69990_misc_general_500.jpeg',
#   'https://www.liverpoolfc.com/team/first-team/player/naby-keita'],
#  ['Jordan Henderson',
#   '14',
#   'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69958_misc_general_500.jpeg',
#   'https://www.liverpoolfc.com/team/first-team/player/jordan-henderson'],
#  ['Adam Lallana',
#   '20',
#   'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/72/thumb_71689_misc_general_500.jpeg',
#   'https://www.liverpoolfc.com/team/first-team/player/adam-lallana'],
#  ['Alex Oxlade-Chamberlain',
#   '21',
#   'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/72/thumb_71693_misc_general_500.jpeg',
#   'https://www.liverpoolfc.com/team/first-team/player/alex-oxlade-chamberlain'],
#  ['Xherdan Shaqiri',
#   '23',
#   'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/71/thumb_70009_misc_general_500.jpeg',
#   'https://www.liverpoolfc.com/team/first-team/player/xherdan-shaqiri'],
#  ['Curtis Jones',
#   '48',
#   'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69988_misc_general_500.jpeg',
#   'https://www.liverpoolfc.com/team/first-team/player/curtis-jones'],
#  ['Ben Woodburn',
#   '58',
#   'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/50/thumb_49325_misc_general_500.jpeg',
#   'https://www.liverpoolfc.com/team/first-team/player/ben-woodburn'],
#  ['Rafael Camacho',
#   '64',
#   'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69949_misc_general_500.jpeg',
#   'https://www.liverpoolfc.com/team/first-team/player/rafael-camacho'],
#  ['Roberto Firmino',
#   '9',
#   'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69955_misc_general_500.jpeg',
#   'https://www.liverpoolfc.com/team/first-team/player/roberto-firmino'],
#  ['Sadio Mane',
#   '10',
#   'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69997_misc_general_500.jpeg',
#   'https://www.liverpoolfc.com/team/first-team/player/sadio-mane'],
#  ['Mohamed Salah',
#   '11',
#   'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/71/thumb_70007_misc_general_500.jpeg',
#   'https://www.liverpoolfc.com/team/first-team/player/mohamed-salah'],
#  ['Daniel Sturridge',
#   '15',
#   'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/71/thumb_70010_misc_general_500.jpeg',
#   'https://www.liverpoolfc.com/team/first-team/player/daniel-sturridge'],
#  ['Rhian Brewster',
#   '24',
#   'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/72/thumb_71688_misc_general_500.jpeg',
#   'https://www.liverpoolfc.com/team/first-team/player/rhian-brewster'],
#  ['Divock Origi',
#   '27',
#   'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/71/thumb_70001_misc_general_500.jpeg',
#   'https://www.liverpoolfc.com/team/first-team/player/divock-origi'],
#  ['Loris Karius',
#   '1',
#   'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69989_misc_general_500.jpeg',
#   'https://www.liverpoolfc.com/team/first-team/player/loris-karius'],
#  ['Nathaniel Clyne',
#   '2',
#   'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69952_misc_general_500.jpeg',
#   'https://www.liverpoolfc.com/team/first-team/player/nathaniel-clyne'],
#  ['Marko Grujic',
#   '16',
#   'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69957_misc_general_500.jpeg',
#   'https://www.liverpoolfc.com/team/first-team/player/marko-grujic'],
#  ['Danny Ings',
#   '28',
#   'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69959_misc_general_500.jpeg',
#   'https://www.liverpoolfc.com/team/first-team/player/danny-ings'],
#  ['Adam Bogdan',
#   '34',
#   'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/50/thumb_49294_misc_general_500.jpeg',
#   'https://www.liverpoolfc.com/team/first-team/player/adam-bogdan'],
#  ['Ryan Kent',
#   '40',
#   'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/50/thumb_49306_misc_general_500.jpeg',
#   'https://www.liverpoolfc.com/team/first-team/player/ryan-kent'],
#  ['Ovie Ejaria',
#   '53',
#   'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/50/thumb_49298_misc_general_500.jpeg',
#   'https://www.liverpoolfc.com/team/first-team/player/ovie-ejaria'],
#  ['Sheyi Ojo',
#   '54',
#   'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/26/thumb_25355_misc_general_500.jpeg',
#   'https://www.liverpoolfc.com/team/first-team/player/sheyi-ojo'],
#  ['Harry Wilson',
#   '59',
#   'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/50/thumb_49324_misc_general_500.jpeg',
#   'https://www.liverpoolfc.com/team/first-team/player/harry-wilson'],
#  ['Pedro Chirivella',
#   '68',
#   'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/26/thumb_25335_misc_general_500.jpeg',
#   'https://www.liverpoolfc.com/team/first-team/player/pedro-chirivella'],
#  ['Kamil Grabara',
#   '73',
#   'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69964_misc_general_500.jpeg',
#   'https://www.liverpoolfc.com/team/first-team/player/kamil-grabara'],
#  ['Allan',
#   '',
#   'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/24/thumb_23741_misc_general_500.jpeg',
#   'https://www.liverpoolfc.com/team/first-team/player/allan'],
#  ['Taiwo Awoniyi',
#   '',
#   'https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/69/thumb_68336_misc_general_500.jpeg',
#   'https://www.liverpoolfc.com/team/first-team/player/taiwo-awoniyi']]

# %%
pd.options.display.max_colwidth = 0

# %%
df = pd.DataFrame(lst, columns = ['name','number','img_url','link'])
df
# Out:
#                        name number  \
# 0   Alisson Becker           13
# 1   Simon Mignolet           22
# 2   Caoimhin Kelleher        62
# 3   Virgil van Dijk          4
# 4   Dejan Lovren             6
# 5   Joe Gomez                12
# 6   Alberto Moreno           18
# 7   Andy Robertson           26
# 8   Joel Matip               32
# 9   Nathaniel Phillips       47
# 10  Trent Alexander-Arnold   66
# 11  Fabinho                  3
# 12  Georginio Wijnaldum      5
# 13  James Milner             7
# 14  Naby Keita               8
# 15  Jordan Henderson         14
# 16  Adam Lallana             20
# 17  Alex Oxlade-Chamberlain  21
# 18  Xherdan Shaqiri          23
# 19  Curtis Jones             48
# 20  Ben Woodburn             58
# 21  Rafael Camacho           64
# 22  Roberto Firmino          9
# 23  Sadio Mane               10
# 24  Mohamed Salah            11
# 25  Daniel Sturridge         15
# 26  Rhian Brewster           24
# 27  Divock Origi             27
# 28  Loris Karius             1
# 29  Nathaniel Clyne          2
# 30  Marko Grujic             16
# 31  Danny Ings               28
# 32  Adam Bogdan              34
# 33  Ryan Kent                40
# 34  Ovie Ejaria              53
# 35  Sheyi Ojo                54
# 36  Harry Wilson             59
# 37  Pedro Chirivella         68
# 38  Kamil Grabara            73
# 39  Allan
# 40  Taiwo Awoniyi
#
#                                                                                                   img_url  \
# 0   https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_
# 17  https://www.liverpoolfc.com/team/first-team/player/alex-oxlade-chamberlain
# 18  https://www.liverpoolfc.com/team/first-team/player/xherdan-shaqiri
# 19  https://www.liverpoolfc.com/team/first-team/player/curtis-jones
# 20  https://www.liverpoolfc.com/team/first-team/player/ben-woodburn
# 21  https://www.liverpoolfc.com/team/first-team/player/rafael-camacho
# 22  https://www.liverpoolfc.com/team/first-team/player/roberto-firmino
# 23  https://www.liverpoolfc.com/team/first-team/player/sadio-mane
# 24  https://www.liverpoolfc.com/team/first-team/player/mohamed-salah
# 25  https://www.liverpoolfc.com/team/first-team/player/daniel-sturridge
# 26  https://www.liverpoolfc.com/team/first-team/player/rhian-brewster
# 27  https://www.liverpoolfc.com/team/first-team/player/divock-origi
# 28  https://www.liverpoolfc.com/team/first-team/player/loris-karius
# 29  https://www.liverpoolfc.com/team/first-team/player/nathaniel-clyne
# 30  https://www.liverpoolfc.com/team/first-team/player/marko-grujic
# 31  https://www.liverpoolfc.com/team/first-team/player/danny-ings
# 32  https://www.liverpoolfc.com/team/first-team/player/adam-bogdan
# 33  https://www.liverpoolfc.com/team/first-team/player/ryan-kent
# 34  https://www.liverpoolfc.com/team/first-team/player/ovie-ejaria
# 35  https://www.liverpoolfc.com/team/first-team/player/sheyi-ojo
# 36  https://www.liverpoolfc.com/team/first-team/player/harry-wilson
# 37  https://www.liverpoolfc.com/team/first-team/player/pedro-chirivella
# 38  https://www.liverpoolfc.com/team/first-team/player/kamil-grabara
# 39  https://www.liverpoolfc.com/team/first-team/player/allan
# 40  https://www.liverpoolfc.com/team/first-team/player/taiwo-awoniyi

# %%
from IPython.display import HTML

# %%
def to_html_img(url, alt = None, width = 100):
    if alt == None:
        alt =''
    return f'<img alt= "{alt}" src = "{url}" width = "{width}"/>'

# %%
to_html_img('https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69996_misc_general_500.jpeg')
# Out:
# '<img alt= "" src = "https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_69996_misc_general_500.jpeg" width = "100"/>'

# %%
df['img']=df.apply(lambda r: to_html_img(r['img_url'], r['name']), axis = 1)
df
# Out:
#                        name number  \
# 0   Alisson Becker           13
# 1   Simon Mignolet           22
# 2   Caoimhin Kelleher        62
# 3   Virgil van Dijk          4
# 4   Dejan Lovren             6
# 5   Joe Gomez                12
# 6   Alberto Moreno           18
# 7   Andy Robertson           26
# 8   Joel Matip               32
# 9   Nathaniel Phillips       47
# 10  Trent Alexander-Arnold   66
# 11  Fabinho                  3
# 12  Georginio Wijnaldum      5
# 13  James Milner             7
# 14  Naby Keita               8
# 15  Jordan Henderson         14
# 16  Adam Lallana             20
# 17  Alex Oxlade-Chamberlain  21
# 18  Xherdan Shaqiri          23
# 19  Curtis Jones             48
# 20  Ben Woodburn             58
# 21  Rafael Camacho           64
# 22  Roberto Firmino          9
# 23  Sadio Mane               10
# 24  Mohamed Salah            11
# 25  Daniel Sturridge         15
# 26  Rhian Brewster           24
# 27  Divock Origi             27
# 28  Loris Karius             1
# 29  Nathaniel Clyne          2
# 30  Marko Grujic             16
# 31  Danny Ings               28
# 32  Adam Bogdan              34
# 33  Ryan Kent                40
# 34  Ovie Ejaria              53
# 35  Sheyi Ojo                54
# 36  Harry Wilson             59
# 37  Pedro Chirivella         68
# 38  Kamil Grabara            73
# 39  Allan
# 40  Taiwo Awoniyi
#
#                                                                                                   img_url  \
# 0   https://d3j2s6hdd6a7rg.cloudfront.net/v2/uploads/media/misc/0001/70/thumb_